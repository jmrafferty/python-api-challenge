# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#pip install citipy -- done from command line

# %%
# Dependencies and Setup
import citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#step 1: Get URL using for loop to pull in

city_weatherInfo = []

for city in cities:
    url = "https://api.openweathermap.org/data/2.5/weather?q=" + city +"&appid=" + weather_api_key
    
    try:
        weather_info = requests.get(url).json()
        print(weather_info)
        #step 2: append each city's info into a list
        city_weatherInfo.append(weather_info)
    except: 
        print("Whoops!")
    #Wait a second in loop to not over exceed rate limit of API
    time.sleep(1.01)
# Out:
# {'coord': {'lon': -104.7, 'lat': 19.22}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 304.22, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1012, 'humidity': 79}, 'visibility': 19312, 'wind': {'speed': 6.2, 'deg': 250}, 'clouds': {'all': 5}, 'dt': 1581293514, 'sys': {'type': 1, 'id': 7166, 'country': 'MX', 'sunrise': 1581255028, 'sunset': 1581296138}, 'timezone': -21600, 'id': 3985168, 'name': 'San Patricio', 'cod': 200}
# {'coord': {'lon': -22.43, 'lat': 63.84}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 269.94, 'feels_like': 261.46, 'temp_min': 267.59, 'temp_max': 271.15, 'pressure': 958, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 8.2, 'deg': 20}, 'clouds': {'all': 40}, 'dt': 1581293516, 'sys': {'type': 1, 'id': 90, 'country': 'IS', 'sunrise': 1581327724, 'sunset': 1581356757}, 'timezone': 0, 'id': 3416888, 'name': 'Grindavik', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 82.18, 'lat': 29.27}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 268.94, 'feels_like': 263.66, 'temp_min': 268.94, 'temp_max': 268.94, 'pressure': 1029, 'humidity': 20, 'sea_level': 1029, 'grnd_level': 723}, 'wind': {'speed': 2.25, 'deg': 93}, 'clouds': {'all': 0}, 'dt': 1581293518, 'sys': {'country': 'NP', 'sunrise': 1581297309, 'sunset': 1581336957}, 'timezone': 20700, 'id': 1283285, 'name': 'Jumla', 'cod': 200}
# {'coord': {'lon': 129.48, 'lat': 28.37}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.08, 'feels_like': 283.84, 'temp_min': 287.15, 'temp_max': 289.15, 'pressure': 1023, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 340}, 'clouds': {'all': 75}, 'dt': 1581293519, 'sys': {'type': 1, 'id': 8013, 'country': 'JP', 'sunrise': 1581285891, 'sunset': 1581325671}, 'timezone': 32400, 'id': 1855540, 'name': 'Naze', 'cod': 200}
# {'coord': {'lon': 101.77, 'lat': 36.62}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'model', 'main': {'temp': 265.51, 'feels_like': 260.44, 'temp_min': 265.51, 'temp_max': 265.51, 'pressure': 1021, 'humidity': 40, 'sea_level': 1021, 'grnd_level': 758}, 'wind': {'speed': 2.18, 'deg': 273}, 'clouds': {'all': 16}, 'dt': 1581293541, 'sys': {'country': 'CN', 'sunrise': 1581293252, 'sunset': 1581331611}, 'timezone': 28800, 'id': 1788852, 'name': 'Xining', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 55.77, 'lat': -21.36}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 293.58, 'feels_like': 293.57, 'temp_min': 289.26, 'temp_max': 295.15, 'pressure': 1011, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 50}, 'rain': {'3h': 0.13}, 'clouds': {'all': 5}, 'dt': 1581293544, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1581300249, 'sunset': 1581346695}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# {'coord': {'lon': 57.52, 'lat': -20.52}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 297.53, 'feels_like': 297.79, 'temp_min': 296.48, 'temp_max': 298.15, 'pressure': 1010, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 180}, 'clouds': {'all': 75}, 'dt': 1581293545, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1581299891, 'sunset': 1581346213}, 'timezone': 14400, 'id': 933995, 'name': 'Souillac', 'cod': 200}
# {'coord': {'lon': 167.48, 'lat': -22.67}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'model', 'main': {'temp': 300.31, 'feels_like': 299.18, 'temp_min': 300.31, 'temp_max': 300.31, 'pressure': 1009, 'humidity': 83, 'sea_level': 1009, 'grnd_level': 1009}, 'wind': {'speed': 9.94, 'deg': 96}, 'rain': {'3h': 0.13}, 'clouds': {'all': 97}, 'dt': 1581293546, 'sys': {'country': 'NC', 'sunrise': 1581273329, 'sunset': 1581319992}, 'timezone': 39600, 'id': 2137773, 'name': 'Vao', 'cod': 200}
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 287.59, 'feels_like': 283.12, 'temp_min': 287.59, 'temp_max': 287.59, 'pressure': 1024, 'humidity': 78}, 'wind': {'speed': 6.71, 'deg': 231, 'gust': 12.07}, 'clouds': {'all': 55}, 'dt': 1581293548, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1581270618, 'sunset': 1581322042}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# {'coord': {'lon': 9.84, 'lat': 44.11}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 282.94, 'feels_like': 282.58, 'temp_min': 280.37, 'temp_max': 285.37, 'pressure': 1028, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 0.5}, 'rain': {'1h': 0.76}, 'clouds': {'all': 90}, 'dt': 1581293549, 'sys': {'type': 1, 'id': 6803, 'country': 'IT', 'sunrise': 1581316093, 'sunset': 1581352898}, 'timezone': 3600, 'id': 3175081, 'name': 'La Spezia', 'cod': 200}
# {'coord': {'lon': 19.23, 'lat': -34.42}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 293.03, 'feels_like': 290.95, 'temp_min': 292.04, 'temp_max': 294.26, 'pressure': 1015, 'humidity': 94}, 'wind': {'speed': 7.52, 'deg': 122}, 'clouds': {'all': 1}, 'dt': 1581293550, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1581307931, 'sunset': 1581356553}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# {'coord': {'lon': 15.64, 'lat': 78.22}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 263.15, 'feels_like': 254.03, 'temp_min': 263.15, 'temp_max': 263.15, 'pressure': 981, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 8.2, 'deg': 110}, 'clouds': {'all': 20}, 'dt': 1581293551, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'model', 'main': {'temp': 298.65, 'feels_like': 297.71, 'temp_min': 298.65, 'temp_max': 298.65, 'pressure': 1017, 'humidity': 77, 'sea_level': 1017, 'grnd_level': 1017}, 'wind': {'speed': 7.44, 'deg': 107}, 'clouds': {'all': 10}, 'dt': 1581293553, 'sys': {'country': 'PF', 'sunrise': 1581259477, 'sunset': 1581306220}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 289.15, 'feels_like': 284.63, 'temp_min': 289.15, 'temp_max': 289.15, 'pressure': 1011, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 360}, 'clouds': {'all': 75}, 'dt': 1581293554, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1581239587, 'sunset': 1581294107}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# {'coord': {'lon': 178.42, 'lat': 69.38}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 243.92, 'feels_like': 235.39, 'temp_min': 243.92, 'temp_max': 243.92, 'pressure': 1027, 'humidity': 91, 'sea_level': 1027, 'grnd_level': 1026}, 'wind': {'speed': 6.71, 'deg': 292}, 'clouds': {'all': 82}, 'dt': 1581293555, 'sys': {'country': 'RU', 'sunrise': 1581282234, 'sunset': 1581305837}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# {'coord': {'lon': 17.94, 'lat': -33.01}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 291.15, 'feels_like': 288.73, 'temp_min': 291.15, 'temp_max': 291.15, 'pressure': 1016, 'humidity': 82}, 'wind': {'speed': 5.7, 'deg': 210}, 'clouds': {'all': 0}, 'dt': 1581293556, 'sys': {'type': 1, 'id': 1943, 'country': 'ZA', 'sunrise': 1581308374, 'sunset': 1581356729}, 'timezone': 7200, 'id': 3361934, 'name': 'Saldanha', 'cod': 200}
# {'coord': {'lon': -102.2, 'lat': 17.96}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'model', 'main': {'temp': 300.1, 'feels_like': 301.78, 'temp_min': 300.1, 'temp_max': 300.1, 'pressure': 1012, 'humidity': 62, 'sea_level': 1012, 'grnd_level': 1000}, 'wind': {'speed': 2.25, 'deg': 217}, 'clouds': {'all': 0}, 'dt': 1581293558, 'sys': {'country': 'MX', 'sunrise': 1581254341, 'sunset': 1581295626}, 'timezone': -21600, 'id': 4026082, 'name': 'Ciudad Lazaro Cardenas', 'cod': 200}
# {'coord': {'lon': 147.88, 'lat': 45.23}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'model', 'main': {'temp': 269.64, 'feels_like': 256.45, 'temp_min': 269.64, 'temp_max': 269.64, 'pressure': 998, 'humidity': 87, 'sea_level': 998, 'grnd_level': 981}, 'wind': {'speed': 15.06, 'deg': 319}, 'snow': {'3h': 1.19}, 'clouds': {'all': 74}, 'dt': 1581293527, 'sys': {'country': 'RU', 'sunrise': 1581283131, 'sunset': 1581319599}, 'timezone': 36000, 'id': 2123979, 'name': 'Kurilsk', 'cod': 200}
# {'coord': {'lon': 67.71, 'lat': 47.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 258.64, 'feels_like': 253.13, 'temp_min': 258.64, 'temp_max': 258.64, 'pressure': 1019, 'humidity': 89, 'sea_level': 1019, 'grnd_level': 966}, 'wind': {'speed': 2.99, 'deg': 3}, 'clouds': {'all': 80}, 'dt': 1581293560, 'sys': {'country': 'KZ', 'sunrise': 1581302689, 'sunset': 1581338523}, 'timezone': 21600, 'id': 1516589, 'name': 'Zhezkazgan', 'cod': 200}
# {'coord': {'lon': -50.01, 'lat': -24.79}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 292.35, 'feels_like': 294.88, 'temp_min': 292.35, 'temp_max': 292.35, 'pressure': 1013, 'humidity': 96, 'sea_level': 1013, 'grnd_level': 904}, 'wind': {'speed': 0.72, 'deg': 44}, 'rain': {'3h': 4}, 'clouds': {'all': 92}, 'dt': 1581293561, 'sys': {'country': 'BR', 'sunrise': 1581238946, 'sunset': 1581285968}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# {'coord': {'lon': -17.1, 'lat': 32.67}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 287.89, 'feels_like': 284.02, 'temp_min': 285.93, 'temp_max': 290.15, 'pressure': 1033, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 10}, 'clouds': {'all': 20}, 'dt': 1581293562, 'sys': {'type': 1, 'id': 6894, 'country': 'PT', 'sunrise': 1581321406, 'sunset': 1581360517}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# {'coord': {'lon': -53.46, 'lat': -33.7}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'model', 'main': {'temp': 289.79, 'feels_like': 287.6, 'temp_min': 289.79, 'temp_max': 289.79, 'pressure': 1019, 'humidity': 75, 'sea_level': 1019, 'grnd_level': 1019}, 'wind': {'speed': 4.09, 'deg': 191}, 'clouds': {'all': 27}, 'dt': 1581293564, 'sys': {'country': 'UY', 'sunrise': 1581238998, 'sunset': 1581287573}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}
# {'coord': {'lon': -133.04, 'lat': 69.45}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 242.15, 'feels_like': 237.56, 'temp_min': 242.15, 'temp_max': 242.15, 'pressure': 1016, 'humidity': 74}, 'visibility': 24140, 'wind': {'speed': 1, 'deg': 120}, 'clouds': {'all': 90}, 'dt': 1581293565, 'sys': {'type': 1, 'id': 942, 'country': 'CA', 'sunrise': 1581270667, 'sunset': 1581294103}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# {'coord': {'lon': -69.36, 'lat': 77.48}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 249.44, 'feels_like': 245.39, 'temp_min': 249.44, 'temp_max': 249.44, 'pressure': 988, 'humidity': 62, 'sea_level': 988, 'grnd_level': 948}, 'wind': {'speed': 0.34, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1581293566, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# {'coord': {'lon': 165.15, 'lat': -21.35}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'model', 'main': {'temp': 301.28, 'feels_like': 301.63, 'temp_min': 301.28, 'temp_max': 301.28, 'pressure': 1007, 'humidity': 77, 'sea_level': 1007, 'grnd_level': 1006}, 'wind': {'speed': 7.56, 'deg': 122}, 'rain': {'3h': 0.19}, 'clouds': {'all': 100}, 'dt': 1581293568, 'sys': {'country': 'NC', 'sunrise': 1581273988, 'sunset': 1581320452}, 'timezone': 39600, 'id': 2138522, 'name': 'Poya', 'cod': 200}
# {'coord': {'lon': -28.7, 'lat': 38.52}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 287.79, 'feels_like': 286.39, 'temp_min': 287.79, 'temp_max': 287.79, 'pressure': 1034, 'humidity': 94, 'sea_level': 1034, 'grnd_level': 1009}, 'wind': {'speed': 3.66, 'deg': 238}, 'clouds': {'all': 100}, 'dt': 1581293569, 'sys': {'country': 'PT', 'sunrise': 1581238391, 'sunset': 1581276294}, 'timezone': -3600, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# {'coord': {'lon': -42.03, 'lat': -22.97}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 301.02, 'feels_like': 303.41, 'temp_min': 301.02, 'temp_max': 301.02, 'pressure': 1012, 'humidity': 74, 'sea_level': 1012, 'grnd_level': 1011}, 'wind': {'speed': 3.91, 'deg': 324}, 'clouds': {'all': 4}, 'dt': 1581293570, 'sys': {'country': 'BR', 'sunrise': 1581237173, 'sunset': 1581283911}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# {'coord': {'lon': -70.92, 'lat': -53.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 293.15, 'feels_like': 288.93, 'temp_min': 293.15, 'temp_max': 293.15, 'pressure': 1011, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 280}, 'clouds': {'all': 40}, 'dt': 1581293438, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1581240560, 'sunset': 1581294392}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# {'coord': {'lon': 72.89, 'lat': 2.67}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 300.75, 'feels_like': 302.62, 'temp_min': 300.75, 'temp_max': 300.75, 'pressure': 1010, 'humidity': 79, 'sea_level': 1010, 'grnd_level': 1010}, 'wind': {'speed': 5.32, 'deg': 67}, 'clouds': {'all': 68}, 'dt': 1581293573, 'sys': {'country': 'MV', 'sunrise': 1581297724, 'sunset': 1581341002}, 'timezone': 18000, 'id': 1337607, 'name': 'Kudahuvadhoo', 'cod': 200}
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 304.57, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1011, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 90}, 'clouds': {'all': 20}, 'dt': 1581293574, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1581355716, 'sunset': 1581402096}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 296.86, 'feels_like': 294.11, 'temp_min': 296.48, 'temp_max': 297.15, 'pressure': 1014, 'humidity': 50}, 'visibility': 16093, 'wind': {'speed': 5.1, 'deg': 140}, 'clouds': {'all': 20}, 'dt': 1581293576, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1581268336, 'sunset': 1581309050}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# {'coord': {'lon': -46.05, 'lat': 60.92}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 265.15, 'feels_like': 260.31, 'temp_min': 265.15, 'temp_max': 265.15, 'pressure': 984, 'humidity': 57}, 'wind': {'speed': 2.1, 'deg': 60}, 'snow': {'3h': 0.12}, 'clouds': {'all': 100}, 'dt': 1581293577, 'sys': {'type': 1, 'id': 47, 'country': 'GL', 'sunrise': 1581246238, 'sunset': 1581276776}, 'timezone': -10800, 'id': 3421719, 'name': 'Narsaq', 'cod': 200}
# {'coord': {'lon': -73.41, 'lat': 41.37}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 275.05, 'feels_like': 272.12, 'temp_min': 270.93, 'temp_max': 279.15, 'pressure': 1031, 'humidity': 74}, 'visibility': 16093, 'wind': {'speed': 0.92, 'deg': 168}, 'clouds': {'all': 75}, 'dt': 1581293578, 'sys': {'type': 1, 'id': 4403, 'country': 'US', 'sunrise': 1581249416, 'sunset': 1581286731}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# {'coord': {'lon': 26.4, 'lat': 46.43}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 270.28, 'feels_like': 262.39, 'temp_min': 270.15, 'temp_max': 270.37, 'pressure': 1024, 'humidity': 92}, 'visibility': 8000, 'wind': {'speed': 7.7, 'deg': 170}, 'clouds': {'all': 14}, 'dt': 1581293579, 'sys': {'type': 1, 'id': 6909, 'country': 'RO', 'sunrise': 1581312410, 'sunset': 1581348632}, 'timezone': 7200, 'id': 686090, 'name': 'Asau', 'cod': 200}
# {'coord': {'lon': 100.34, 'lat': 5.41}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 299.58, 'feels_like': 302.15, 'temp_min': 298.71, 'temp_max': 300.15, 'pressure': 1011, 'humidity': 74}, 'visibility': 9000, 'wind': {'speed': 2.6, 'deg': 20}, 'clouds': {'all': 20}, 'dt': 1581293401, 'sys': {'type': 1, 'id': 9438, 'country': 'MY', 'sunrise': 1581291308, 'sunset': 1581334242}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# {'coord': {'lon': -105.2, 'lat': 20.7}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 300.04, 'feels_like': 300.98, 'temp_min': 299.26, 'temp_max': 301.15, 'pressure': 1013, 'humidity': 61}, 'visibility': 24140, 'wind': {'speed': 3.1, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1581293582, 'sys': {'type': 1, 'id': 7156, 'country': 'MX', 'sunrise': 1581255252, 'sunset': 1581296154}, 'timezone': -21600, 'id': 4004293, 'name': 'Ixtapa', 'cod': 200}
# {'coord': {'lon': 57.7, 'lat': -20.41}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09n'}], 'base': 'stations', 'main': {'temp': 297.52, 'feels_like': 297.78, 'temp_min': 296.48, 'temp_max': 298.15, 'pressure': 1010, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 5.1, 'deg': 180}, 'clouds': {'all': 75}, 'dt': 1581293583, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1581299855, 'sunset': 1581346162}, 'timezone': 14400, 'id': 934322, 'name': 'Mahebourg', 'cod': 200}
# {'coord': {'lon': -7.72, 'lat': 4.38}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 298.6, 'feels_like': 302.95, 'temp_min': 298.6, 'temp_max': 298.6, 'pressure': 1013, 'humidity': 90, 'sea_level': 1013, 'grnd_level': 1010}, 'wind': {'speed': 1.83, 'deg': 241}, 'clouds': {'all': 8}, 'dt': 1581293584, 'sys': {'country': 'LR', 'sunrise': 1581317176, 'sunset': 1581360244}, 'timezone': 0, 'id': 2276492, 'name': 'Harper', 'cod': 200}
# {'coord': {'lon': 92.55, 'lat': 55.96}, 'weather': [{'id': 613, 'main': 'Snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 273.15, 'feels_like': 269.91, 'temp_min': 273.15, 'temp_max': 273.15, 'pressure': 991, 'humidity': 97}, 'visibility': 1900, 'wind': {'speed': 1.7, 'deg': 328}, 'clouds': {'all': 90}, 'dt': 1581293585, 'sys': {'type': 1, 'id': 8957, 'country': 'RU', 'sunrise': 1581298094, 'sunset': 1581331195}, 'timezone': 25200, 'id': 1495797, 'name': 'Ovsyanka', 'cod': 200}
# {'coord': {'lon': -73.97, 'lat': 42.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 270.64, 'feels_like': 266.61, 'temp_min': 267.59, 'temp_max': 273.15, 'pressure': 1031, 'humidity': 86}, 'visibility': 16093, 'wind': {'speed': 2.1, 'deg': 350}, 'clouds': {'all': 90}, 'dt': 1581293567, 'sys': {'type': 1, 'id': 5782, 'country': 'US', 'sunrise': 1581249689, 'sunset': 1581286727}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'model', 'main': {'temp': 300.74, 'feels_like': 300.08, 'temp_min': 300.74, 'temp_max': 300.74, 'pressure': 1010, 'humidity': 75, 'sea_level': 1010, 'grnd_level': 1009}, 'wind': {'speed': 8.23, 'deg': 85}, 'clouds': {'all': 28}, 'dt': 1581293589, 'sys': {'country': 'PF', 'sunrise': 1581261389, 'sunset': 1581306256}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# {'coord': {'lon': -79.24, 'lat': 42.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 272.72, 'feels_like': 267.18, 'temp_min': 272.04, 'temp_max': 273.71, 'pressure': 1023, 'humidity': 86}, 'visibility': 16093, 'wind': {'speed': 4.6, 'deg': 180}, 'clouds': {'all': 90}, 'dt': 1581293342, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1581250896, 'sunset': 1581288050}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# {'coord': {'lon': 13.77, 'lat': 56.16}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 281.17, 'feels_like': 273.95, 'temp_min': 280.37, 'temp_max': 282.15, 'pressure': 975, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 8.7, 'deg': 210, 'gust': 14.4}, 'rain': {'3h': 2.25}, 'clouds': {'all': 100}, 'dt': 1581293592, 'sys': {'type': 1, 'id': 1759, 'country': 'SE', 'sunrise': 1581317013, 'sunset': 1581350091}, 'timezone': 3600, 'id': 2707399, 'name': 'Haessleholm', 'cod': 200}
# {'coord': {'lon': -134.42, 'lat': 58.3}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 277.98, 'feels_like': 274.08, 'temp_min': 277.15, 'temp_max': 278.71, 'pressure': 1030, 'humidity': 80}, 'visibility': 16093, 'wind': {'speed': 3.1, 'deg': 50}, 'clouds': {'all': 90}, 'dt': 1581293440, 'sys': {'type': 1, 'id': 7729, 'country': 'US', 'sunrise': 1581266730, 'sunset': 1581298703}, 'timezone': -32400, 'id': 5554072, 'name': 'Juneau', 'cod': 200}
# {'coord': {'lon': 177.28, 'lat': -38.08}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 296.48, 'feels_like': 296.57, 'temp_min': 296.48, 'temp_max': 296.48, 'pressure': 1018, 'humidity': 60}, 'wind': {'speed': 2.24, 'deg': 340, 'gust': 5.36}, 'clouds': {'all': 1}, 'dt': 1581293594, 'sys': {'type': 3, 'id': 2000325, 'country': 'NZ', 'sunrise': 1581269598, 'sunset': 1581319020}, 'timezone': 46800, 'id': 2208332, 'name': 'Opotiki', 'cod': 200}
# {'coord': {'lon': -52.95, 'lat': 5.38}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 299.44, 'feels_like': 298.21, 'temp_min': 299.44, 'temp_max': 299.44, 'pressure': 1015, 'humidity': 74, 'sea_level': 1015, 'grnd_level': 1015}, 'wind': {'speed': 7.94, 'deg': 54}, 'rain': {'3h': 0.13}, 'clouds': {'all': 80}, 'dt': 1581293596, 'sys': {'country': 'GF', 'sunrise': 1581241698, 'sunset': 1581284628}, 'timezone': -10800, 'id': 3380290, 'name': 'Sinnamary', 'cod': 200}
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 292.63, 'feels_like': 293.69, 'temp_min': 292.04, 'temp_max': 293.15, 'pressure': 1020, 'humidity': 82}, 'wind': {'speed': 1.5, 'deg': 220}, 'rain': {'3h': 0.19}, 'clouds': {'all': 33}, 'dt': 1581293597, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1581307726, 'sunset': 1581356369}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# {'coord': {'lon': 80.55, 'lat': 73.51}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 247.15, 'feels_like': 241.3, 'temp_min': 247.15, 'temp_max': 247.15, 'pressure': 997, 'humidity': 89, 'sea_level': 997, 'grnd_level': 996}, 'wind': {'speed': 2.95, 'deg': 105}, 'clouds': {'all': 0}, 'dt': 1581293598, 'sys': {'country': 'RU', 'sunrise': 1581309310, 'sunset': 1581325739}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# {'coord': {'lon': 115.33, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 289.32, 'feels_like': 289.18, 'temp_min': 288.71, 'temp_max': 289.82, 'pressure': 1018, 'humidity': 69}, 'wind': {'speed': 0.45, 'deg': 86, 'gust': 2.24}, 'clouds': {'all': 0}, 'dt': 1581293599, 'sys': {'type': 3, 'id': 2020551, 'country': 'AU', 'sunrise': 1581284925, 'sunset': 1581333430}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# {'coord': {'lon': 141.97, 'lat': -38.27}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 291.25, 'feels_like': 289.09, 'temp_min': 291.25, 'temp_max': 291.25, 'pressure': 1011, 'humidity': 88, 'sea_level': 1011, 'grnd_level': 1011}, 'wind': {'speed': 5.97, 'deg': 110}, 'clouds': {'all': 100}, 'dt': 1581293601, 'sys': {'country': 'AU', 'sunrise': 1581278059, 'sunset': 1581327508}, 'timezone': 39600, 'id': 2171099, 'name': 'Codrington', 'cod': 200}
# {'coord': {'lon': 18.42, 'lat': -33.93}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 292.68, 'feels_like': 287.58, 'temp_min': 292.04, 'temp_max': 293.15, 'pressure': 1018, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 9.8, 'deg': 190}, 'clouds': {'all': 20}, 'dt': 1581293363, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1581308172, 'sunset': 1581356700}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# {'coord': {'lon': 167.72, 'lat': -45.42}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'model', 'main': {'temp': 283.41, 'feels_like': 282.09, 'temp_min': 283.41, 'temp_max': 283.41, 'pressure': 1022, 'humidity': 82, 'sea_level': 1022, 'grnd_level': 969}, 'wind': {'speed': 1, 'deg': 325}, 'clouds': {'all': 23}, 'dt': 1581293603, 'sys': {'country': 'NZ', 'sunrise': 1581271000, 'sunset': 1581322207}, 'timezone': 46800, 'id': 2181625, 'name': 'Te Anau', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 138.95, 'lat': 34.67}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 277.98, 'feels_like': 272.27, 'temp_min': 275.93, 'temp_max': 279.26, 'pressure': 1015, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 4.6, 'deg': 50}, 'clouds': {'all': 75}, 'dt': 1581293606, 'sys': {'type': 1, 'id': 8070, 'country': 'JP', 'sunrise': 1581284153, 'sunset': 1581322863}, 'timezone': 32400, 'id': 1852357, 'name': 'Shimoda', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -46.12, 'lat': -20.97}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 292.63, 'feels_like': 294, 'temp_min': 292.63, 'temp_max': 292.63, 'pressure': 1016, 'humidity': 94, 'sea_level': 1016, 'grnd_level': 921}, 'wind': {'speed': 2.33, 'deg': 14}, 'clouds': {'all': 91}, 'dt': 1581293629, 'sys': {'country': 'BR', 'sunrise': 1581238307, 'sunset': 1581284741}, 'timezone': -10800, 'id': 3466901, 'name': 'Carmo do Rio Claro', 'cod': 200}
# {'coord': {'lon': -68.66, 'lat': -9.07}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 298.46, 'feels_like': 302.21, 'temp_min': 298.46, 'temp_max': 298.46, 'pressure': 1009, 'humidity': 80, 'sea_level': 1009, 'grnd_level': 989}, 'wind': {'speed': 1.06, 'deg': 345}, 'rain': {'3h': 0.25}, 'clouds': {'all': 36}, 'dt': 1581293630, 'sys': {'country': 'BR', 'sunrise': 1581244545, 'sunset': 1581289322}, 'timezone': -18000, 'id': 3662155, 'name': 'Sena Madureira', 'cod': 200}
# {'coord': {'lon': 30.48, 'lat': -22.95}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 293.45, 'feels_like': 295.62, 'temp_min': 293.45, 'temp_max': 293.45, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 942}, 'wind': {'speed': 1.72, 'deg': 242}, 'rain': {'3h': 5}, 'clouds': {'all': 79}, 'dt': 1581293631, 'sys': {'country': 'ZA', 'sunrise': 1581306202, 'sunset': 1581352881}, 'timezone': 7200, 'id': 949224, 'name': 'Thohoyandou', 'cod': 200}
# {'coord': {'lon': -156.79, 'lat': 71.29}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 245.15, 'feels_like': 236.95, 'temp_min': 245.15, 'temp_max': 245.15, 'pressure': 1014, 'humidity': 68}, 'visibility': 2414, 'wind': {'speed': 6.2, 'deg': 60}, 'clouds': {'all': 90}, 'dt': 1581293633, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1581277700, 'sunset': 1581298470}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# {'coord': {'lon': -25.58, 'lat': 37.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 287.15, 'feels_like': 285.85, 'temp_min': 287.15, 'temp_max': 287.15, 'pressure': 1036, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 2.69, 'deg': 221}, 'clouds': {'all': 20}, 'dt': 1581293634, 'sys': {'type': 1, 'id': 6899, 'country': 'PT', 'sunrise': 1581237570, 'sunset': 1581275618}, 'timezone': -3600, 'id': 3372745, 'name': 'Rabo de Peixe', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': -27.07, 'lat': 38.73}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 290.15, 'feels_like': 290.36, 'temp_min': 290.15, 'temp_max': 290.15, 'pressure': 1034, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 2, 'deg': 190}, 'clouds': {'all': 75}, 'dt': 1581293636, 'sys': {'type': 1, 'id': 6895, 'country': 'PT', 'sunrise': 1581238022, 'sunset': 1581275881}, 'timezone': -3600, 'id': 3372760, 'name': 'Praia da Vitoria', 'cod': 200}
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 287.59, 'feels_like': 283.12, 'temp_min': 287.59, 'temp_max': 287.59, 'pressure': 1024, 'humidity': 78}, 'wind': {'speed': 6.71, 'deg': 231, 'gust': 12.07}, 'clouds': {'all': 92}, 'dt': 1581293638, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1581270686, 'sunset': 1581322228}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# {'coord': {'lon': 5.14, 'lat': 61.99}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 277.76, 'feels_like': 269.15, 'temp_min': 277.04, 'temp_max': 278.15, 'pressure': 945, 'humidity': 93}, 'wind': {'speed': 10.3, 'deg': 240}, 'clouds': {'all': 100}, 'dt': 1581293639, 'sys': {'type': 1, 'id': 1616, 'country': 'NO', 'sunrise': 1581320523, 'sunset': 1581350724}, 'timezone': 3600, 'id': 3146487, 'name': 'Raudeberg', 'cod': 200}
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 301.81, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 7.2, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1581293640, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1581250286, 'sunset': 1581293992}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# {'coord': {'lon': 40.25, 'lat': 62.22}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 273.94, 'feels_like': 269.36, 'temp_min': 273.94, 'temp_max': 273.94, 'pressure': 997, 'humidity': 91, 'sea_level': 997, 'grnd_level': 984}, 'wind': {'speed': 3.6, 'deg': 223}, 'clouds': {'all': 100}, 'dt': 1581293641, 'sys': {'country': 'RU', 'sunrise': 1581312183, 'sunset': 1581342210}, 'timezone': 10800, 'id': 495983, 'name': 'Shalakusha', 'cod': 200}
# {'coord': {'lon': 120.26, 'lat': -9.66}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 301.75, 'feels_like': 302.59, 'temp_min': 301.75, 'temp_max': 301.75, 'pressure': 1010, 'humidity': 74, 'sea_level': 1010, 'grnd_level': 1010}, 'wind': {'speed': 6.7, 'deg': 283}, 'clouds': {'all': 100}, 'dt': 1581293643, 'sys': {'country': 'ID', 'sunrise': 1581285574, 'sunset': 1581330414}, 'timezone': 28800, 'id': 1622318, 'name': 'Waingapu', 'cod': 200}
# {'coord': {'lon': 27.91, 'lat': -33.02}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 295.38, 'feels_like': 296.11, 'temp_min': 295.38, 'temp_max': 295.38, 'pressure': 1019, 'humidity': 81, 'sea_level': 1019, 'grnd_level': 1015}, 'wind': {'speed': 3.45, 'deg': 113}, 'rain': {'3h': 0.31}, 'clouds': {'all': 80}, 'dt': 1581293644, 'sys': {'country': 'ZA', 'sunrise': 1581305979, 'sunset': 1581354338}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# {'coord': {'lon': -79.15, 'lat': -7.84}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 295.15, 'feels_like': 295.94, 'temp_min': 295.15, 'temp_max': 295.15, 'pressure': 1011, 'humidity': 88}, 'visibility': 7000, 'wind': {'speed': 4.1, 'deg': 150}, 'clouds': {'all': 75}, 'dt': 1581293645, 'sys': {'type': 1, 'id': 8690, 'country': 'PE', 'sunrise': 1581247144, 'sunset': 1581291759}, 'timezone': -18000, 'id': 3698359, 'name': 'Chicama', 'cod': 200}
# {'coord': {'lon': 170.31, 'lat': 69.7}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 239.02, 'feels_like': 233.05, 'temp_min': 239.02, 'temp_max': 239.02, 'pressure': 1030, 'humidity': 97, 'sea_level': 1030, 'grnd_level': 1029}, 'wind': {'speed': 2.97, 'deg': 155}, 'clouds': {'all': 59}, 'dt': 1581293646, 'sys': {'country': 'RU', 'sunrise': 1581284381, 'sunset': 1581307582}, 'timezone': 43200, 'id': 2122090, 'name': 'Pevek', 'cod': 200}
# {'coord': {'lon': 132.75, 'lat': -5.67}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'model', 'main': {'temp': 301.13, 'feels_like': 301.11, 'temp_min': 301.13, 'temp_max': 301.13, 'pressure': 1010, 'humidity': 79, 'sea_level': 1010, 'grnd_level': 1007}, 'wind': {'speed': 8.33, 'deg': 311}, 'rain': {'3h': 2.44}, 'clouds': {'all': 79}, 'dt': 1581293647, 'sys': {'country': 'ID', 'sunrise': 1581282832, 'sunset': 1581327160}, 'timezone': 32400, 'id': 1623197, 'name': 'Tual', 'cod': 200}
# {'coord': {'lon': 143.3, 'lat': 59.38}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 252.26, 'feels_like': 247.56, 'temp_min': 252.26, 'temp_max': 252.26, 'pressure': 1020, 'humidity': 59, 'sea_level': 1020, 'grnd_level': 1008}, 'wind': {'speed': 1.32, 'deg': 353}, 'clouds': {'all': 58}, 'dt': 1581293649, 'sys': {'country': 'RU', 'sunrise': 1581286708, 'sunset': 1581318221}, 'timezone': 36000, 'id': 2122605, 'name': 'Okhotsk', 'cod': 200}
# {'coord': {'lon': -51.19, 'lat': 68.82}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'model', 'main': {'temp': 254.22, 'feels_like': 248.67, 'temp_min': 254.22, 'temp_max': 254.22, 'pressure': 990, 'humidity': 96, 'sea_level': 990, 'grnd_level': 974}, 'wind': {'speed': 2.84, 'deg': 160}, 'snow': {'3h': 0.25}, 'clouds': {'all': 100}, 'dt': 1581293650, 'sys': {'country': 'GL', 'sunrise': 1581250696, 'sunset': 1581274785}, 'timezone': -10800, 'id': 3420768, 'name': 'Qasigiannguit', 'cod': 200}
# {'coord': {'lon': 112.4, 'lat': 66.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 246.15, 'feels_like': 239.52, 'temp_min': 246.15, 'temp_max': 246.15, 'pressure': 988, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 50, 'gust': 9}, 'clouds': {'all': 75}, 'dt': 1581293651, 'sys': {'type': 1, 'id': 8846, 'country': 'RU', 'sunrise': 1581296459, 'sunset': 1581323302}, 'timezone': 32400, 'id': 2014624, 'name': 'Udachny', 'cod': 200}
# {'coord': {'lon': 108.48, 'lat': 22.75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 285.15, 'feels_like': 284.47, 'temp_min': 285.15, 'temp_max': 285.15, 'pressure': 1023, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 1}, 'clouds': {'all': 75}, 'dt': 1581293652, 'sys': {'type': 1, 'id': 9628, 'country': 'CN', 'sunrise': 1581290504, 'sunset': 1581331139}, 'timezone': 28800, 'id': 1798480, 'name': 'Pumiao', 'cod': 200}
# {'coord': {'lon': 70.7, 'lat': 20.79}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'model', 'main': {'temp': 292.64, 'feels_like': 285.25, 'temp_min': 292.64, 'temp_max': 292.64, 'pressure': 1014, 'humidity': 23, 'sea_level': 1014, 'grnd_level': 1005}, 'wind': {'speed': 7.29, 'deg': 36}, 'clouds': {'all': 11}, 'dt': 1581293654, 'sys': {'country': 'IN', 'sunrise': 1581299428, 'sunset': 1581340349}, 'timezone': 19800, 'id': 1266397, 'name': 'Kodinar', 'cod': 200}
# {'coord': {'lon': 38.84, 'lat': 58.04}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 269.55, 'feels_like': 264.24, 'temp_min': 269.55, 'temp_max': 269.55, 'pressure': 1009, 'humidity': 93, 'sea_level': 1009, 'grnd_level': 992}, 'wind': {'speed': 3.92, 'deg': 222}, 'clouds': {'all': 90}, 'dt': 1581293655, 'sys': {'country': 'RU', 'sunrise': 1581311414, 'sunset': 1581343657}, 'timezone': 10800, 'id': 500004, 'name': 'Rybinsk', 'cod': 200}
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 296.24, 'feels_like': 293.76, 'temp_min': 293.15, 'temp_max': 300.15, 'pressure': 1011, 'humidity': 51}, 'visibility': 16093, 'wind': {'speed': 4.6, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1581293627, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1581267154, 'sunset': 1581308201}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# {'coord': {'lon': 26.89, 'lat': -33.59}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 292.59, 'feels_like': 293.57, 'temp_min': 292.59, 'temp_max': 292.59, 'pressure': 1018, 'humidity': 96}, 'wind': {'speed': 3.08, 'deg': 88}, 'rain': {'3h': 0.37}, 'clouds': {'all': 68}, 'dt': 1581293657, 'sys': {'type': 3, 'id': 2011314, 'country': 'ZA', 'sunrise': 1581306170, 'sunset': 1581354636}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# {'coord': {'lon': -76.22, 'lat': -13.7}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 294.7, 'feels_like': 286.03, 'temp_min': 294.26, 'temp_max': 295.15, 'pressure': 1011, 'humidity': 30}, 'visibility': 10000, 'wind': {'speed': 10.3, 'deg': 210}, 'clouds': {'all': 72}, 'dt': 1581293658, 'sys': {'type': 1, 'id': 8691, 'country': 'PE', 'sunrise': 1581246051, 'sunset': 1581291445}, 'timezone': -18000, 'id': 3932145, 'name': 'Pisco', 'cod': 200}
# {'coord': {'lon': -97.86, 'lat': 55.74}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 258.15, 'feels_like': 253.93, 'temp_min': 258.15, 'temp_max': 258.15, 'pressure': 1007, 'humidity': 77}, 'visibility': 24140, 'wind': {'speed': 1}, 'clouds': {'all': 75}, 'dt': 1581293515, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1581257407, 'sunset': 1581290477}, 'timezone': -21600, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 10.26, 'lat': 5.63}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 290.06, 'feels_like': 290.6, 'temp_min': 290.06, 'temp_max': 290.06, 'pressure': 1014, 'humidity': 86, 'sea_level': 1014, 'grnd_level': 882}, 'wind': {'speed': 1.31, 'deg': 267}, 'clouds': {'all': 72}, 'dt': 1581293662, 'sys': {'country': 'CM', 'sunrise': 1581312939, 'sunset': 1581355850}, 'timezone': 3600, 'id': 2227613, 'name': 'Mbouda', 'cod': 200}
# {'coord': {'lon': 73, 'lat': 5.67}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 300.85, 'feels_like': 301.84, 'temp_min': 300.85, 'temp_max': 300.85, 'pressure': 1010, 'humidity': 76, 'sea_level': 1010, 'grnd_level': 1010}, 'wind': {'speed': 6.13, 'deg': 87}, 'clouds': {'all': 3}, 'dt': 1581293663, 'sys': {'country': 'MV', 'sunrise': 1581297885, 'sunset': 1581340788}, 'timezone': 18000, 'id': 1337619, 'name': 'Ugoofaaru', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 21.29, 'lat': 29.11}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 284.67, 'feels_like': 281.37, 'temp_min': 284.67, 'temp_max': 284.67, 'pressure': 1032, 'humidity': 58, 'sea_level': 1032, 'grnd_level': 1025}, 'wind': {'speed': 2.71, 'deg': 341}, 'clouds': {'all': 0}, 'dt': 1581293666, 'sys': {'country': 'LY', 'sunrise': 1581311903, 'sunset': 1581351592}, 'timezone': 7200, 'id': 88533, 'name': 'Awjilah', 'cod': 200}
# {'coord': {'lon': 118.57, 'lat': -20.32}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 302.33, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1006, 'humidity': 70}, 'wind': {'speed': 7.2, 'deg': 290}, 'clouds': {'all': 90}, 'dt': 1581293667, 'sys': {'type': 1, 'id': 9585, 'country': 'AU', 'sunrise': 1581285248, 'sunset': 1581331552}, 'timezone': 28800, 'id': 2063042, 'name': 'Port Hedland', 'cod': 200}
# {'coord': {'lon': -126.83, 'lat': 65.28}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 256.15, 'feels_like': 251.55, 'temp_min': 256.15, 'temp_max': 256.15, 'pressure': 1015, 'humidity': 84}, 'visibility': 40233, 'wind': {'speed': 1.5, 'deg': 340}, 'clouds': {'all': 75}, 'dt': 1581293668, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1581267062, 'sunset': 1581294728}, 'timezone': -25200, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# {'coord': {'lon': 53.35, 'lat': 47.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 262.96, 'feels_like': 257.05, 'temp_min': 262.96, 'temp_max': 262.96, 'pressure': 1030, 'humidity': 52, 'sea_level': 1030, 'grnd_level': 1032}, 'wind': {'speed': 3.42, 'deg': 18}, 'clouds': {'all': 0}, 'dt': 1581293669, 'sys': {'country': 'KZ', 'sunrise': 1581306111, 'sunset': 1581341994}, 'timezone': 18000, 'id': 608872, 'name': 'Makat', 'cod': 200}
# {'coord': {'lon': 122.27, 'lat': 43.61}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'model', 'main': {'temp': 258.62, 'feels_like': 252.99, 'temp_min': 258.62, 'temp_max': 258.62, 'pressure': 1024, 'humidity': 87, 'sea_level': 1024, 'grnd_level': 1000}, 'wind': {'speed': 3.14, 'deg': 87}, 'clouds': {'all': 43}, 'dt': 1581293671, 'sys': {'country': 'CN', 'sunrise': 1581289075, 'sunset': 1581325948}, 'timezone': 28800, 'id': 2034400, 'name': 'Tongliao', 'cod': 200}
# {'coord': {'lon': 80.86, 'lat': 59.06}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'model', 'main': {'temp': 244.25, 'feels_like': 238.26, 'temp_min': 244.25, 'temp_max': 244.25, 'pressure': 1008, 'humidity': 99, 'sea_level': 1008, 'grnd_level': 1000}, 'wind': {'speed': 3.1, 'deg': 277}, 'clouds': {'all': 15}, 'dt': 1581293672, 'sys': {'country': 'RU', 'sunrise': 1581301588, 'sunset': 1581333313}, 'timezone': 25200, 'id': 1504382, 'name': 'Kargasok', 'cod': 200}
# {'coord': {'lon': -84.53, 'lat': 39.18}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 276.65, 'feels_like': 272.33, 'temp_min': 274.26, 'temp_max': 279.26, 'pressure': 1019, 'humidity': 82}, 'visibility': 16093, 'wind': {'speed': 3.49, 'deg': 190}, 'rain': {'1h': 0.35}, 'clouds': {'all': 90}, 'dt': 1581293471, 'sys': {'type': 1, 'id': 4476, 'country': 'US', 'sunrise': 1581251848, 'sunset': 1581289637}, 'timezone': -18000, 'id': 4513583, 'name': 'Hamilton', 'cod': 200}
# {'coord': {'lon': 172.79, 'lat': 3.07}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'model', 'main': {'temp': 302.2, 'feels_like': 303.46, 'temp_min': 302.2, 'temp_max': 302.2, 'pressure': 1007, 'humidity': 81, 'sea_level': 1007, 'grnd_level': 1007}, 'wind': {'speed': 7.77, 'deg': 80}, 'rain': {'3h': 0.25}, 'clouds': {'all': 55}, 'dt': 1581293684, 'sys': {'country': 'KI', 'sunrise': 1581273773, 'sunset': 1581316999}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# {'coord': {'lon': 145.43, 'lat': -17}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 304.09, 'feels_like': 308.87, 'temp_min': 302.59, 'temp_max': 305.15, 'pressure': 1007, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 0.5, 'deg': 10}, 'rain': {'3h': 0.31}, 'clouds': {'all': 94}, 'dt': 1581293686, 'sys': {'type': 1, 'id': 9490, 'country': 'AU', 'sunrise': 1581279036, 'sunset': 1581324870}, 'timezone': 36000, 'id': 2158767, 'name': 'Mareeba', 'cod': 200}
# {'coord': {'lon': 82.47, 'lat': 65.7}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 244.95, 'feels_like': 238.72, 'temp_min': 244.95, 'temp_max': 244.95, 'pressure': 997, 'humidity': 99, 'sea_level': 997, 'grnd_level': 993}, 'wind': {'speed': 3.47, 'deg': 212}, 'clouds': {'all': 82}, 'dt': 1581293708, 'sys': {'country': 'RU', 'sunrise': 1581303314, 'sunset': 1581330814}, 'timezone': 18000, 'id': 1502073, 'name': "Krasnosel'kup", 'cod': 200}
# ...
# {'coord': {'lon': -90.87, 'lat': 42.48}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 271.95, 'feels_like': 264.96, 'temp_min': 269.15, 'temp_max': 273.71, 'pressure': 1013, 'humidity': 92}, 'visibility': 8047, 'wind': {'speed': 6.7, 'deg': 350}, 'clouds': {'all': 90}, 'dt': 1581294547, 'sys': {'type': 1, 'id': 3792, 'country': 'US', 'sunrise': 1581253728, 'sunset': 1581290800}, 'timezone': -21600, 'id': 4854534, 'name': 'Dubuque', 'cod': 200}
# {'coord': {'lon': 33.04, 'lat': 66.08}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 273.99, 'feels_like': 268.22, 'temp_min': 273.99, 'temp_max': 273.99, 'pressure': 981, 'humidity': 91, 'sea_level': 981, 'grnd_level': 969}, 'wind': {'speed': 5.31, 'deg': 202}, 'clouds': {'all': 98}, 'dt': 1581294548, 'sys': {'country': 'RU', 'sunrise': 1581315307, 'sunset': 1581342547}, 'timezone': 10800, 'id': 533964, 'name': 'Loukhi', 'cod': 200}
# {'coord': {'lon': -80.09, 'lat': 26.93}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 295.08, 'feels_like': 289.42, 'temp_min': 294.26, 'temp_max': 296.15, 'pressure': 1026, 'humidity': 56}, 'visibility': 16093, 'wind': {'speed': 9.3, 'deg': 80, 'gust': 11.8}, 'clouds': {'all': 40}, 'dt': 1581294449, 'sys': {'type': 1, 'id': 5314, 'country': 'US', 'sunrise': 1581249691, 'sunset': 1581289662}, 'timezone': -18000, 'id': 4160610, 'name': 'Jupiter', 'cod': 200}
# {'coord': {'lon': -71.7, 'lat': 46.76}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 257.24, 'feels_like': 252.37, 'temp_min': 255.15, 'temp_max': 258.15, 'pressure': 1029, 'humidity': 70}, 'visibility': 14484, 'wind': {'speed': 1.82, 'deg': 25}, 'clouds': {'all': 90}, 'dt': 1581294551, 'sys': {'type': 1, 'id': 879, 'country': 'CA', 'sunrise': 1581249661, 'sunset': 1581285665}, 'timezone': -18000, 'id': 7535681, 'name': 'Pont-Rouge', 'cod': 200}
# {'coord': {'lon': 41.34, 'lat': 61.05}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'model', 'main': {'temp': 271.94, 'feels_like': 266.9, 'temp_min': 271.94, 'temp_max': 271.94, 'pressure': 1001, 'humidity': 96, 'sea_level': 1001, 'grnd_level': 980}, 'wind': {'speed': 4.02, 'deg': 235}, 'snow': {'3h': 0.38}, 'clouds': {'all': 99}, 'dt': 1581294552, 'sys': {'country': 'RU', 'sunrise': 1581311578, 'sunset': 1581342292}, 'timezone': 10800, 'id': 491029, 'name': 'Solginskiy', 'cod': 200}
# {'coord': {'lon': -75.83, 'lat': 42.25}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 272.75, 'feels_like': 268.03, 'temp_min': 270.93, 'temp_max': 274.26, 'pressure': 1026, 'humidity': 74}, 'visibility': 16093, 'wind': {'speed': 3.1, 'deg': 160}, 'clouds': {'all': 75}, 'dt': 1581294553, 'sys': {'type': 1, 'id': 3429, 'country': 'US', 'sunrise': 1581250095, 'sunset': 1581287214}, 'timezone': -18000, 'id': 5110365, 'name': 'Broome', 'cod': 200}
# {'coord': {'lon': 117.78, 'lat': 30.95}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 280.6, 'feels_like': 277.95, 'temp_min': 280.6, 'temp_max': 280.6, 'pressure': 1025, 'humidity': 71, 'sea_level': 1025, 'grnd_level': 1018}, 'wind': {'speed': 1.52, 'deg': 132}, 'clouds': {'all': 83}, 'dt': 1581294554, 'sys': {'country': 'CN', 'sunrise': 1581288907, 'sunset': 1581328271}, 'timezone': 28800, 'id': 1792621, 'name': 'Tongling', 'cod': 200}
# {'coord': {'lon': 49.82, 'lat': 7.98}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 297.12, 'feels_like': 295.1, 'temp_min': 297.12, 'temp_max': 297.12, 'pressure': 1013, 'humidity': 79, 'sea_level': 1013, 'grnd_level': 1011}, 'wind': {'speed': 8.23, 'deg': 29}, 'clouds': {'all': 7}, 'dt': 1581294556, 'sys': {'country': 'SO', 'sunrise': 1581303593, 'sunset': 1581346207}, 'timezone': 10800, 'id': 60019, 'name': 'Eyl', 'cod': 200}
# {'coord': {'lon': -158.09, 'lat': 21.35}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 297.73, 'feels_like': 295.43, 'temp_min': 295.15, 'temp_max': 299.15, 'pressure': 1011, 'humidity': 56}, 'visibility': 16093, 'wind': {'speed': 5.7, 'deg': 340, 'gust': 9.8}, 'clouds': {'all': 75}, 'dt': 1581294557, 'sys': {'type': 1, 'id': 7866, 'country': 'US', 'sunrise': 1581267988, 'sunset': 1581308807}, 'timezone': -36000, 'id': 5850554, 'name': 'Makakilo City', 'cod': 200}
# {'coord': {'lon': -169.92, 'lat': -19.06}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 301.15, 'feels_like': 304.33, 'temp_min': 301.15, 'temp_max': 301.15, 'pressure': 1011, 'humidity': 78}, 'wind': {'speed': 3.6, 'deg': 60}, 'clouds': {'all': 68}, 'dt': 1581294558, 'sys': {'type': 1, 'id': 7306, 'country': 'NU', 'sunrise': 1581268170, 'sunset': 1581314303}, 'timezone': -39600, 'id': 4036284, 'name': 'Alofi', 'cod': 200}
# {'coord': {'lon': 152.85, 'lat': -25.3}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 303.24, 'feels_like': 306.89, 'temp_min': 302.15, 'temp_max': 304.82, 'pressure': 1008, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 330}, 'clouds': {'all': 40}, 'dt': 1581294559, 'sys': {'type': 1, 'id': 9501, 'country': 'AU', 'sunrise': 1581276638, 'sunset': 1581323707}, 'timezone': 36000, 'id': 2146219, 'name': 'Hervey Bay', 'cod': 200}
# {'coord': {'lon': -50.21, 'lat': -30.18}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'model', 'main': {'temp': 296.19, 'feels_like': 293.29, 'temp_min': 296.19, 'temp_max': 296.19, 'pressure': 1016, 'humidity': 71, 'sea_level': 1016, 'grnd_level': 1016}, 'wind': {'speed': 7.83, 'deg': 159}, 'rain': {'3h': 0.44}, 'clouds': {'all': 24}, 'dt': 1581294560, 'sys': {'country': 'BR', 'sunrise': 1581238543, 'sunset': 1581286468}, 'timezone': -10800, 'id': 3466165, 'name': 'Cidreira', 'cod': 200}
# {'coord': {'lon': 27.67, 'lat': 64.17}, 'weather': [{'id': 615, 'main': 'Snow', 'description': 'light rain and snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 275.15, 'feels_like': 267.57, 'temp_min': 275.15, 'temp_max': 275.15, 'pressure': 974, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 8.2, 'deg': 160, 'gust': 16.5}, 'clouds': {'all': 90}, 'dt': 1581294562, 'sys': {'type': 1, 'id': 1344, 'country': 'FI', 'sunrise': 1581315843, 'sunset': 1581344589}, 'timezone': 7200, 'id': 654901, 'name': 'Kajaani', 'cod': 200}
# {'coord': {'lon': 140.83, 'lat': 35.73}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 274.18, 'feels_like': 270.66, 'temp_min': 273.15, 'temp_max': 275.93, 'pressure': 1016, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 2.1, 'deg': 300}, 'clouds': {'all': 75}, 'dt': 1581294563, 'sys': {'type': 1, 'id': 7955, 'country': 'JP', 'sunrise': 1581283800, 'sunset': 1581322314}, 'timezone': 32400, 'id': 2112802, 'name': 'Hasaki', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 124.39, 'lat': 13.78}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'model', 'main': {'temp': 297.97, 'feels_like': 293.75, 'temp_min': 297.97, 'temp_max': 297.97, 'pressure': 1018, 'humidity': 76, 'sea_level': 1018, 'grnd_level': 1018}, 'wind': {'speed': 11.51, 'deg': 42}, 'rain': {'3h': 0.56}, 'clouds': {'all': 100}, 'dt': 1581294565, 'sys': {'country': 'PH', 'sunrise': 1581286071, 'sunset': 1581327934}, 'timezone': 28800, 'id': 1712961, 'name': 'Gigmoto', 'cod': 200}
# {'coord': {'lon': 127.67, 'lat': 26.18}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 288.17, 'feels_like': 280.55, 'temp_min': 287.15, 'temp_max': 289.15, 'pressure': 1025, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 8.7, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1581294567, 'sys': {'type': 1, 'id': 8137, 'country': 'JP', 'sunrise': 1581286155, 'sunset': 1581326276}, 'timezone': 32400, 'id': 1850108, 'name': 'Tomigusuku', 'cod': 200}
# {'coord': {'lon': 128.92, 'lat': -3.33}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'model', 'main': {'temp': 301.44, 'feels_like': 301.25, 'temp_min': 301.44, 'temp_max': 301.44, 'pressure': 1011, 'humidity': 75, 'sea_level': 1011, 'grnd_level': 1011}, 'wind': {'speed': 8.1, 'deg': 342}, 'clouds': {'all': 31}, 'dt': 1581294568, 'sys': {'country': 'ID', 'sunrise': 1581283900, 'sunset': 1581327931}, 'timezone': 32400, 'id': 1651591, 'name': 'Amahai', 'cod': 200}
# {'coord': {'lon': -68.15, 'lat': -16.5}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 279.15, 'feels_like': 276.76, 'temp_min': 279.15, 'temp_max': 279.15, 'pressure': 1038, 'humidity': 100}, 'visibility': 6000, 'wind': {'speed': 2.1, 'deg': 60}, 'clouds': {'all': 90}, 'dt': 1581294106, 'sys': {'type': 1, 'id': 8648, 'country': 'BO', 'sunrise': 1581243919, 'sunset': 1581289703}, 'timezone': -14400, 'id': 3911925, 'name': 'La Paz', 'cod': 200}
# {'coord': {'lon': 111.62, 'lat': -2.68}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 296.56, 'feels_like': 300.79, 'temp_min': 296.56, 'temp_max': 296.56, 'pressure': 1011, 'humidity': 94, 'sea_level': 1011, 'grnd_level': 1009}, 'wind': {'speed': 0.97, 'deg': 20}, 'clouds': {'all': 100}, 'dt': 1581294301, 'sys': {'country': 'ID', 'sunrise': 1581288093, 'sunset': 1581332042}, 'timezone': 25200, 'id': 1632694, 'name': 'Pangkalanbuun', 'cod': 200}
# {'coord': {'lon': 136.42, 'lat': -13.85}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 304.15, 'feels_like': 308.67, 'temp_min': 304.15, 'temp_max': 304.15, 'pressure': 1007, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 2.6, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1581294571, 'sys': {'type': 1, 'id': 9527, 'country': 'AU', 'sunrise': 1581281416, 'sunset': 1581326815}, 'timezone': 34200, 'id': 2079582, 'name': 'Alyangula', 'cod': 200}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'coord': {'lon': 11.58, 'lat': 1.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 293.62, 'feels_like': 296.6, 'temp_min': 293.62, 'temp_max': 293.62, 'pressure': 1013, 'humidity': 97, 'sea_level': 1013, 'grnd_level': 938}, 'wind': {'speed': 1.01, 'deg': 239}, 'clouds': {'all': 71}, 'dt': 1581294575, 'sys': {'country': 'GA', 'sunrise': 1581312371, 'sunset': 1581355784}, 'timezone': 3600, 'id': 2396646, 'name': 'Oyem', 'cod': 200}
# {'coord': {'lon': 71.72, 'lat': 40.43}, 'weather': [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 281.88, 'feels_like': 278.49, 'temp_min': 280.15, 'temp_max': 284.15, 'pressure': 1014, 'humidity': 56}, 'visibility': 4400, 'wind': {'speed': 2.1, 'deg': 230}, 'clouds': {'all': 99}, 'dt': 1581294576, 'sys': {'type': 1, 'id': 9014, 'country': 'UZ', 'sunrise': 1581300841, 'sunset': 1581338446}, 'timezone': 18000, 'id': 1513491, 'name': 'Yangi Marg`ilon', 'cod': 200}
# {'coord': {'lon': 126.7, 'lat': 62.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'model', 'main': {'temp': 246.31, 'feels_like': 240.07, 'temp_min': 246.31, 'temp_max': 246.31, 'pressure': 1009, 'humidity': 99, 'sea_level': 1009, 'grnd_level': 974}, 'wind': {'speed': 3.52, 'deg': 98}, 'clouds': {'all': 100}, 'dt': 1581294599, 'sys': {'country': 'RU', 'sunrise': 1581291440, 'sunset': 1581321457}, 'timezone': 32400, 'id': 2026861, 'name': 'Berdigestyakh', 'cod': 200}
# {'coord': {'lon': -8.69, 'lat': 43.21}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 287.08, 'feels_like': 283.39, 'temp_min': 285.15, 'temp_max': 288.71, 'pressure': 1028, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1581294600, 'sys': {'type': 1, 'id': 6403, 'country': 'ES', 'sunrise': 1581320430, 'sunset': 1581357455}, 'timezone': 3600, 'id': 3126369, 'name': 'Carballo', 'cod': 200}
# {'coord': {'lon': 61.93, 'lat': 56.42}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 253.99, 'feels_like': 247.45, 'temp_min': 253.99, 'temp_max': 253.99, 'pressure': 1015, 'humidity': 92, 'sea_level': 1015, 'grnd_level': 992}, 'wind': {'speed': 4.21, 'deg': 227}, 'clouds': {'all': 0}, 'dt': 1581294601, 'sys': {'country': 'RU', 'sunrise': 1581305526, 'sunset': 1581338461}, 'timezone': 18000, 'id': 1504826, 'name': "Kamensk-Ural'skiy", 'cod': 200}
# {'coord': {'lon': 111.93, 'lat': 22.03}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'model', 'main': {'temp': 286.17, 'feels_like': 284.72, 'temp_min': 286.17, 'temp_max': 286.17, 'pressure': 1024, 'humidity': 74, 'sea_level': 1024, 'grnd_level': 1014}, 'wind': {'speed': 1.58, 'deg': 30}, 'clouds': {'all': 0}, 'dt': 1581294603, 'sys': {'country': 'CN', 'sunrise': 1581289624, 'sunset': 1581330362}, 'timezone': 28800, 'id': 1793364, 'name': 'Tangping', 'cod': 200}
# {'coord': {'lon': 78.85, 'lat': 18.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'model', 'main': {'temp': 292.05, 'feels_like': 292.53, 'temp_min': 292.05, 'temp_max': 292.05, 'pressure': 1015, 'humidity': 85, 'sea_level': 1015, 'grnd_level': 963}, 'wind': {'speed': 2.33, 'deg': 87}, 'clouds': {'all': 97}, 'dt': 1581294604, 'sys': {'country': 'IN', 'sunrise': 1581297287, 'sunset': 1581338578}, 'timezone': 19800, 'id': 1256377, 'name': 'Siddipet', 'cod': 200}
# {'coord': {'lon': 150.86, 'lat': -34.58}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 296.92, 'feels_like': 296.75, 'temp_min': 295.37, 'temp_max': 298.71, 'pressure': 1009, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 6.7, 'deg': 80}, 'clouds': {'all': 75}, 'dt': 1581294605, 'sys': {'type': 1, 'id': 9594, 'country': 'AU', 'sunrise': 1581276302, 'sunset': 1581324997}, 'timezone': 39600, 'id': 6255012, 'name': 'Flinders', 'cod': 200}
# {'coord': {'lon': 150.5, 'lat': -23.38}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 304.15, 'feels_like': 307.14, 'temp_min': 304.15, 'temp_max': 304.15, 'pressure': 1007, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 3.1, 'deg': 340}, 'clouds': {'all': 40}, 'dt': 1581294606, 'sys': {'type': 1, 'id': 9499, 'country': 'AU', 'sunrise': 1581277352, 'sunset': 1581324120}, 'timezone': 36000, 'id': 2151437, 'name': 'Rockhampton', 'cod': 200}

# %%
print(city_weatherInfo[0:5])
# Out:
# [{'coord': {'lon': -104.7, 'lat': 19.22}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 302.15, 'feels_like': 304.22, 'temp_min': 302.15, 'temp_max': 302.15, 'pressure': 1012, 'humidity': 79}, 'visibility': 19312, 'wind': {'speed': 6.2, 'deg': 250}, 'clouds': {'all': 5}, 'dt': 1581293514, 'sys': {'type': 1, 'id': 7166, 'country': 'MX', 'sunrise': 1581255028, 'sunset': 1581296138}, 'timezone': -21600, 'id': 3985168, 'name': 'San Patricio', 'cod': 200}, {'coord': {'lon': -22.43, 'lat': 63.84}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 269.94, 'feels_like': 261.46, 'temp_min': 267.59, 'temp_max': 271.15, 'pressure': 958, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 8.2, 'deg': 20}, 'clouds': {'all': 40}, 'dt': 1581293516, 'sys': {'type': 1, 'id': 90, 'country': 'IS', 'sunrise': 1581327724, 'sunset': 1581356757}, 'timezone': 0, 'id': 3416888, 'name': 'Grindavik', 'cod': 200}, {'cod': '404', 'message': 'city not found'}, {'coord': {'lon': 82.18, 'lat': 29.27}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'model', 'main': {'temp': 268.94, 'feels_like': 263.66, 'temp_min': 268.94, 'temp_max': 268.94, 'pressure': 1029, 'humidity': 20, 'sea_level': 1029, 'grnd_level': 723}, 'wind': {'speed': 2.25, 'deg': 93}, 'clouds': {'all': 0}, 'dt': 1581293518, 'sys': {'country': 'NP', 'sunrise': 1581297309, 'sunset': 1581336957}, 'timezone': 20700, 'id': 1283285, 'name': 'Jumla', 'cod': 200}, {'coord': {'lon': 129.48, 'lat': 28.37}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 288.08, 'feels_like': 283.84, 'temp_min': 287.15, 'temp_max': 289.15, 'pressure': 1023, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 5.7, 'deg': 340}, 'clouds': {'all': 75}, 'dt': 1581293519, 'sys': {'type': 1, 'id': 8013, 'country': 'JP', 'sunrise': 1581285891, 'sunset': 1581325671}, 'timezone': 32400, 'id': 1855540, 'name': 'Naze', 'cod': 200}]

# %%
#step 3: Convert to DF

city_weatherDF = pd.DataFrame(city_weatherInfo)

city_weatherDF.head()
#step 4: Create plots
# Out:
#                            coord  \
# 0  {'lon': -104.7, 'lat': 19.22}
# 1  {'lon': -22.43, 'lat': 63.84}
# 2                            NaN
# 3   {'lon': 82.18, 'lat': 29.27}
# 4  {'lon': 129.48, 'lat': 28.37}
#
#                                              weather      base  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations
# 1  [{'id': 802, 'main': 'Clouds', 'description': ...  stations
# 2                                                NaN       NaN
# 3  [{'id': 800, 'main': 'Clear', 'description': '...     model
# 4  [{'id': 803, 'main': 'Clouds', 'description': ...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 302.15, 'feels_like': 304.22, 'temp_m...     19312.0
# 1  {'temp': 269.94, 'feels_like': 261.46, 'temp_m...     10000.0
# 2                                                NaN         NaN
# 3  {'temp': 268.94, 'feels_like': 263.66, 'temp_m...         NaN
# 4  {'temp': 288.08, 'feels_like': 283.84, 'temp_m...     10000.0
#
#                          wind       clouds            dt  \
# 0  {'speed': 6.2, 'deg': 250}   {'all': 5}  1.581294e+09
# 1   {'speed': 8.2, 'deg': 20}  {'all': 40}  1.581294e+09
# 2                         NaN          NaN           NaN
# 3  {'speed': 2.25, 'deg': 93}   {'all': 0}  1.581294e+09
# 4  {'speed': 5.7, 'deg': 340}  {'all': 75}  1.581294e+09
#
#                                                  sys  timezone         id  \
# 0  {'type': 1, 'id': 7166, 'country': 'MX', 'sunr...  -21600.0  3985168.0
# 1  {'type': 1, 'id': 90, 'country': 'IS', 'sunris...       0.0  3416888.0
# 2                                                NaN       NaN        NaN
# 3  {'country': 'NP', 'sunrise': 1581297309, 'suns...   20700.0  1283285.0
# 4  {'type': 1, 'id': 8013, 'country': 'JP', 'sunr...   32400.0  1855540.0
#
#            name  cod         message rain snow
# 0  San Patricio  200             NaN  NaN  NaN
# 1     Grindavik  200             NaN  NaN  NaN
# 2           NaN  404  city not found  NaN  NaN
# 3         Jumla  200             NaN  NaN  NaN
# 4          Naze  200             NaN  NaN  NaN

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
